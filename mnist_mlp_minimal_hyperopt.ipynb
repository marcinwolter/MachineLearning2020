# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/MachineLearning2020/blob/main/mnist_mlp_minimal_hyperopt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop

batch_size = 128
num_classes = 10
epochs = 10 #20

N_TRAIN_EXAMPLES = 3000
N_TEST_EXAMPLES = 1000

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()


x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# print info about a shape of arrays
print(x_train.shape, 'train samples')
print(x_test.shape, 'test samples')
print(y_train.shape, 'train samples')
print(y_test.shape, 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


# take a subset of all MNIST events
x_train = x_train[:N_TRAIN_EXAMPLES]
y_train = y_train[:N_TRAIN_EXAMPLES]
x_test = x_test[:N_TEST_EXAMPLES]
y_test = y_test[:N_TEST_EXAMPLES]

# print info about a shape of arrays
print(x_train.shape, 'train samples after conversion')
print(x_test.shape, 'test samples  after conversion')
print(y_train.shape, 'train samples after conversion')
print(y_test.shape, 'test samples  after conversion')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 784) train samples
# (10000, 784) test samples
# (60000,) train samples
# (10000,) test samples
# (3000, 784) train samples after conversion
# (1000, 784) test samples  after conversion
# (3000, 10) train samples after conversion
# (1000, 10) test samples  after conversion

# %%
space = {

            'units1': hp.quniform('units1', 32,3*1024,1),
            'dropout1': hp.uniform('dropout1', .00,.50),

        }

# %%
def f_nn(params):   

    #print ('Parameters testing: ', params)

    model = Sequential()
    model.add(Dense(int(params['units1']), activation='relu', input_shape=(784,)))
    model.add(Dropout(params['dropout1']))
    model.add(Dense(int(params['units1']), activation='relu'))
    model.add(Dropout(params['dropout1']))
    model.add(Dense(int(params['units1']), activation='relu'))
    model.add(Dropout(params['dropout1']))
    model.add(Dense(num_classes, activation='softmax'))

    #model.summary()

    model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=0,
                    validation_data=(x_test, y_test))
    
    score = model.evaluate(x_test, y_test, verbose=0)
    #print('Test accuracy:', score[1])

    return {'loss': -score[1], 'status': STATUS_OK}

# %% [markdown]
# # **Find the best parameters:**

# %%
trials = Trials()
best = fmin(fn=f_nn, space=space, algo=tpe.suggest, max_evals=50, trials=trials)
# Out:
# 100%|██████████| 50/50 [02:04<00:00,  2.48s/it, best loss: -0.9359999895095825]

# %%
print('best: ', best)
print('best accuracy: ',-trials.best_trial['result']['loss'])

#from hyperopt import space_eval
#print('best parameters: ',space_eval(space, best))
# Out:
# best:  {'dropout1': 0.0633378766008985, 'units1': 1391.0}
# best accuracy:  0.9359999895095825

# %% [markdown]
# # **Visualization**

# %%
print(trials.trials)
# Out:
# [{'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': -0.9150000214576721, 'status': 'ok'}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [0], 'units1': [0]}, 'vals': {'dropout1': [0.46921832268154673], 'units1': [2070.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 30, 452000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 40, 218000)}, {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': -0.9079999923706055, 'status': 'ok'}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [1], 'units1': [1]}, 'vals': {'dropout1': [0.23027934940506734], 'units1': [1742.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 40, 221000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 42, 517000)}, {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': -0.9179999828338623, 'status': 'ok'}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [2], 'units1': [2]}, 'vals': {'dropout1': [0.001256481487814154], 'units1': [415.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 42, 519000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 44, 171000)}, {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': -0.9300000071525574, 'status': 'ok'}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [3], 'units1': [3]}, 'vals': {'dropout1': [0.30922014685420673], 'units1': [2883.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 44, 174000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 47, 910000)}, {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': -0.9229999780654907, 'status': 'ok'}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [4], 'units1': [4]}, 'vals': {'dropout1': [0.026369714526201127], 'units1': [409.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 47, 917000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 49, 754000)}, {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': -0.8980000019073486, 'status': 'ok'}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [5], 'units1': [5]}, 'vals': {'dropout1': [0.24998659126973066], 'units1': [1133.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 49, 756000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 51, 611000)}, {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': -0.8849999904632568, 'status': 'ok'}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [6], 'units1': [6]}, 'vals': {'dropout1': [0.42752047027557577], 'units1': [1577.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 51, 614000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 53, 741000)}, {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': -0.9070000052452087, 'status': 'ok'}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [7], 'units1': [7]}, 'vals': {'dropout1': [0.3601161560939529], 'units1': [208.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 12, 5, 21, 14, 53, 744000), 'refresh_time': datetime.datetime(2020, 12, 5, 21, 14, 55, 421000)}, {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': -0.9300000071525574, 'status': 'ok'}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'dropout1': [8], 'units1': [8]}, 'vals': {'dropout1': [0.44274759290017546],  ...

# %%
from hyperopt import plotting

plotting.main_plot_history(trials)
# Out:
# avg best error: -0.9359999895095825

# %%
plotting.main_plot_histogram(trials)
# Out:
# Showing Histogram of 50 jobs

# %%
plotting.main_plot_vars(trials)
# Out:
# finite loss range -0.9359999895095825 -0.6290000081062317 -1.9359999895095825

# %%
#units vs time

f, ax = plt.subplots(1)
xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['units1'] for t in trials.trials]
ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$units$ $vs$ $time$ ', fontsize=18)
ax.set_xlabel('$time$', fontsize=16)
ax.set_ylabel('$units$', fontsize=16)
# Out:
# Text(0, 0.5, '$units$')

# %%
#units vs time

f, ax = plt.subplots(1)
xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['dropout1'] for t in trials.trials]
ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$dropout$ $vs$ $time$ ', fontsize=18)
ax.set_xlabel('$time$', fontsize=16)
ax.set_ylabel('$dropout$', fontsize=16)
# Out:
# Text(0, 0.5, '$dropout$')

# %%
#dropout vs units

f, ax = plt.subplots(1)
xs = [t['misc']['vals']['units1'] for t in trials.trials]
ys = [t['misc']['vals']['dropout1'] for t in trials.trials]
#ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$dropout$ $vs$ $units$ ', fontsize=18)
ax.set_xlabel('$units$', fontsize=16)
ax.set_ylabel('$dropout$', fontsize=16)
# Out:
# Text(0, 0.5, '$dropout$')

# %%
#value vs units

f, ax = plt.subplots(1)
xs = [t['misc']['vals']['units1'] for t in trials.trials]
ys = [-t['result']['loss'] for t in trials.trials]
#ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$accuracy$ $vs$ $units$ ', fontsize=18)
ax.set_xlabel('$units$', fontsize=16)
ax.set_ylabel('$accuracy$', fontsize=16)
# Out:
# Text(0, 0.5, '$accuracy$')

# %%
#value vs dropout

f, ax = plt.subplots(1)
xs = [t['misc']['vals']['dropout1'] for t in trials.trials]
ys = [-t['result']['loss'] for t in trials.trials]
#ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$accuracy$ $vs$ $dropout$ ', fontsize=18)
ax.set_xlabel('$dropout$', fontsize=16)
ax.set_ylabel('$accuracy$', fontsize=16)
# Out:
# Text(0, 0.5, '$accuracy$')
