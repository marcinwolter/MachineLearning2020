# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/MachineLearning2020/blob/main/gan_generate_letters_failing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""" Simple implementation of Generative Adversarial Neural Network """

# This code is specially modified to generate just one, single digit

import numpy as np

#from IPython.core.debugger import Tracer

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Conv2D
from keras.layers import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam

import matplotlib.pyplot as plt
#plt.switch_backend('agg')   # allows code to run without a system DISPLAY


class GAN(object):
    """ Generative Adversarial Network class """
    def __init__(self, width=28, height=28, channels=1):

        self.width = width
        self.height = height
        self.channels = channels

        self.shape = (self.width, self.height, self.channels)

        self.optimizer = Adam(lr=0.0002, beta_1=0.5, decay=8e-8)

        self.G = self.__generator()
        self.G.compile(loss='binary_crossentropy', optimizer=self.optimizer)

        self.D = self.__discriminator()
        self.D.compile(loss='binary_crossentropy', optimizer=self.optimizer, metrics=['accuracy'])

        self.stacked_generator_discriminator = self.__stacked_generator_discriminator()

        self.stacked_generator_discriminator.compile(loss='binary_crossentropy', optimizer=self.optimizer)


    def __generator(self):
        """ Declare generator """

        model = Sequential()
        model.add(Dense(256, input_shape=(100,)))
        model.add(LeakyReLU(alpha=0.2))
        #model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        #model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(1024))
        model.add(LeakyReLU(alpha=0.2))
        #model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(self.width  * self.height * self.channels, activation='tanh'))
        model.add(Reshape((self.width, self.height, self.channels)))

        return model

    def __discriminator(self):
        """ Declare discriminator """

        model = Sequential()
        model.add(Conv2D(64,(3,3), input_shape=self.shape))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.2))
        model.add(Conv2D(128,(3,3), input_shape=self.shape))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(0.2))
        #model.add(Flatten(input_shape=self.shape))
        #model.add(Dense(15*(self.width * self.height * self.channels), input_shape=self.shape))
        #model.add(LeakyReLU(alpha=0.2))
        #model.add(Dense(15*np.int64((self.width * self.height * self.channels)/2)))
        #model.add(LeakyReLU(alpha=0.2))    
        model.add(Flatten())           
        model.add(Dense(np.int64((self.width * self.height * self.channels))))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(np.int64((self.width * self.height * self.channels))))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(1, activation='sigmoid'))
        model.summary()

        return model

    def __stacked_generator_discriminator(self):

        self.D.trainable = False

        model = Sequential()
        model.add(self.G)
        model.add(self.D)

        return model

    def train(self, X_train, epochs=10000, batch = 32, save_interval = 100):

        for cnt in range(epochs):

            ## train discriminator
            random_index = np.random.randint(0, len(X_train) - int(batch/2))
            legit_images = X_train[random_index : random_index + int(batch/2)].reshape(int(batch/2), self.width, self.height, self.channels)

            gen_noise = np.random.normal(0, 1, (int(batch/2), 100))
            syntetic_images = self.G.predict(gen_noise)

            x_combined_batch = np.concatenate((legit_images, syntetic_images))
            y_combined_batch = np.concatenate((np.ones((int(batch/2), 1)), np.zeros((int(batch/2), 1))))

            d_loss = self.D.train_on_batch(x_combined_batch, y_combined_batch)


            # train generator

            noise = np.random.normal(0, 1, (batch, 100))
            y_mislabled = np.ones((batch, 1))

            g_loss = self.stacked_generator_discriminator.train_on_batch(noise, y_mislabled)

            if cnt % save_interval == 0:
                print ('epoch: %d, [Discriminator :: d_loss: %f], [ Generator :: loss: %f]' % (cnt, d_loss[0], g_loss))

            if cnt % save_interval == 0:
                self.plot_images(save2file=False, step=cnt)


    def plot_images(self, save2file=False, samples=16, step=0):
        ''' Plot generated images '''
        filename = "./mnist_%d.png" % step
        noise = np.random.normal(0, 1, (samples, 100))

        images = self.G.predict(noise)

        plt.figure(figsize=(7, 7))

        for i in range(images.shape[0]):
            plt.subplot(4, 4, i+1)
            image = images[i, :, :, :]
            image = np.reshape(image, [self.height, self.width])
            plt.imshow(image, cmap='gray')
            plt.axis('off')
        plt.tight_layout()

        if save2file:
            plt.savefig(filename)
            plt.close('all')
        else:
            plt.show()


if __name__ == '__main__':
    (X_train, _), (_, _) = mnist.load_data()

    # Rescale -1 to 1
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5
    X_train = np.expand_dims(X_train, axis=3)


    gan = GAN()

    gan.train(X_train)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 26, 26, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 24, 24, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 24, 24, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 73728)             0
# _________________________________________________________________
# dense_11 (Dense)             (None, 784)               57803536
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 784)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 784)               615440
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 784)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 785
# =================================================================
# Total params: 58,494,257
# Trainable params: 58,494,257
# Non-trainable params: 0
# _________________________________________________________________
# epoch: 0, [Discriminator :: d_loss: 0.721117], [ Generator :: loss: 0.539967]
# epoch: 100, [Discriminator :: d_loss: 0.136752], [ Generator :: loss: 2.198554]
# epoch: 200, [Discriminator :: d_loss: 0.042210], [ Generator :: loss: 4.651114]
# epoch: 300, [Discriminator :: d_loss: 0.759467], [ Generator :: loss: 24.176060]
# epoch: 400, [Discriminator :: d_loss: 0.152342], [ Generator :: loss: 5.294930]
# epoch: 500, [Discriminator :: d_loss: 0.043782], [ Generator :: loss: 5.492772]
# epoch: 600, [Discriminator :: d_loss: 0.104454], [ Generator :: loss: 5.119097]
# epoch: 700, [Discriminator :: d_loss: 0.009718], [ Generator :: loss: 6.421110]
# epoch: 800, [Discriminator :: d_loss: 0.017228], [ Generator :: loss: 12.302975]
# epoch: 900, [Discriminator :: d_loss: 0.001972], [ Generator :: loss: 8.129941]
# epoch: 1000, [Discriminator :: d_loss: 0.153033], [ Generator :: loss: 4.566718]
# epoch: 1100, [Discriminator :: d_loss: 1.861422], [ Generator :: loss: 18.520035]
# epoch: 1200, [Discriminator :: d_loss: 0.084827], [ Generator :: loss: 12.861952]
# epoch: 1300, [Discriminator :: d_loss: 0.004794], [ Generator :: loss: 7.579015]
# epoch: 1400, [Discriminator :: d_loss: 0.005358], [ Generator :: loss: 6.383770]
# epoch: 1500, [Discriminator :: d_loss: 0.335148], [ Generator :: loss: 12.823597]
# epoch: 1600, [Discriminator :: d_loss: 0.014154], [ Generator :: loss: 5.337307]
# epoch: 1700, [Discriminator :: d_loss: 0.047234], [ Generator :: loss: 4.850233]
# epoch: 1800, [Discriminator :: d_loss: 0.459956], [ Generator :: loss: 11.966795]
# epoch: 1900, [Discriminator :: d_loss: 0.097304], [ Generator :: loss: 6.389255]
# epoch: 2000, [Discriminator :: d_loss: 0.109941], [ Generator :: loss: 4.863843]
# epoch: 2100, [Discriminator :: d_loss: 0.006976], [ Generator :: loss: 6.892954]
# epoch: 2200, [Discriminator :: d_loss: 0.001595], [ Generator :: loss: 8.162676]
# epoch: 2300, [Discriminator :: d_loss: 0.528339], [ Generator :: loss: 36.263241]
# epoch: 2400, [Discriminator :: d_loss: 0.049755], [ Generator :: loss: 6.105082]
# epoch: 2500, [Discriminator :: d_loss: 0.128428], [ Generator :: loss: 4.984569]
# epoch: 2600, [Discriminator :: d_loss: 0.150481], [ Generator :: loss: 3.257776]
# epoch: 2700, [Discriminator :: d_loss: 0.026493], [ Generator :: loss: 4.973171]
# epoch: 2800, [Discriminator :: d_loss: 0.060864], [ Generator :: loss: 4.176684]
# epoch: 2900, [Discriminator :: d_loss: 0.057969], [ Generator :: loss: 3.723890]
# epoch: 3000, [Discriminator :: d_loss: 0.351973], [ Generator :: loss: 2.674228]
# epoch: 3100, [Discriminator :: d_loss: 0.023615], [ Generator :: loss: 3.867288]
# epoch: 3200, [Discriminator :: d_loss: 0.136549], [ Generator :: loss: 3.550404]
# epoch: 3300, [Discriminator :: d_loss: 0.048998], [ Generator :: loss: 4.609507]
# epoch: 3400, [Discriminator :: d_loss: 0.054500], [ Generator :: loss: 3.016932]
# epoch: 3500, [Discriminator :: d_loss: 0.370456], [ Generator :: loss: 3.228948]
# epoch: 3600, [Discriminator :: d_loss: 0.107749], [ Generator :: loss: 3.440916]
# epoch: 3700, [Discriminator :: d_loss: 0.043879], [ Generator :: loss: 3.982462]
# epoch: 3800, [Discriminator :: d_loss: 0.071281], [ Generator :: loss: 2.788063]
# epoch: 3900, [Discriminator :: d_loss: 0.058830], [ Generator :: loss: 3.446913]
# epoch: 4000, [Discriminator :: d_loss: 0.215055], [ Generator :: loss: 2.812312]
# epoch: 4100, [Discriminator :: d_loss: 0.147242], [ Generator :: loss: 2.276965]
# epoch: 4200, [Discriminator :: d_loss: 0.104290], [ Generator :: loss: 3.118994]
# epoch: 4300, [Discriminator :: d_loss: 0.180609], [ Generator :: loss: 3.303459]
# epoch: 4400, [Discriminator :: d_loss: 0.229719], [ Generator :: loss: 3.043351]
# epoch: 4500, [Discriminator :: d_loss: 0.046626], [ Generator :: loss: 2.938655]
# epoch: 4600, [Discriminator :: d_loss: 0.271690], [ Generator :: loss: 2.972137]
# epoch: 4700, [Discriminator :: d_loss: 0.163062], [ Generator :: loss: 2.625412]
# epoch: 4800, [Discriminator :: d_loss: 0.057871], [ Generator :: loss: 2.963521]
# epoch: 4900, [Discriminator :: d_loss: 0.074829], [ Generator :: loss: 3.514149]
# epoch: 5000, [Discriminator :: d_loss: 0.155242], [ Generator :: loss: 3.300564]
# epoch: 5100, [Discriminator :: d_loss: 0.151998], [ Generator :: loss: 2.876485]
# epoch: 5200, [Discriminator :: d_loss: 0.054199], [ Generator :: loss: 3.989902]
# epoch: 5300, [Discriminator :: d_loss: 0.059224], [ Generator :: loss: 3.582138]
# epoch: 5400, [Discriminator :: d_loss: 0.129450], [ Generator :: loss: 2.806871]
# epoch: 5500, [Discriminator :: d_loss: 0.124623], [ Generator :: loss: 3.073552]
# epoch: 5600, [Discriminator :: d_loss: 0.112163], [ Generator :: loss: 2.368395]
# epoch: 5700, [Discriminator :: d_loss: 0.360295], [ Generator :: loss: 2.171873]
# epoch: 5800, [Discriminator :: d_loss: 0.081024], [ Generator :: loss: 2.981257]
# epoch: 5900, [Discriminator :: d_loss: 0.020772], [ Generator :: loss: 3.885746]
# epoch: 6000, [Discriminator :: d_loss: 0.128258], [ Generator :: loss: 2.652477]
# epoch: 6100, [Discriminator :: d_loss: 0.204903], [ Generator :: loss: 3.985730]
# epoch: 6200, [Discriminator :: d_loss: 0.052819], [ Generator :: loss: 2.736607]
# epoch: 6300, [Discriminator :: d_loss: 0.106777], [ Generator :: loss: 2.710534]
# epoch: 6400, [Discriminator :: d_loss: 0.279274], [ Generator :: loss: 2.506816]
# epoch: 6500, [Discriminator :: d_loss: 0.126642], [ Generator :: loss: 2.463208]
# epoch: 6600, [Discriminator :: d_loss: 0.215041], [ Generator :: loss: 2.698607]
# epoch: 6700, [Discriminator :: d_loss: 0.042655], [ Generator :: loss: 2.861732]
# epoch: 6800, [Discriminator :: d_loss: 0.063782], [ Generator :: loss: 2.952730]
# epoch: 6900, [Discriminator :: d_loss: 0.272246], [ Generator :: loss: 2.754741]
# epoch: 7000, [Discriminator :: d_loss: 0.205981], [ Generator :: loss: 2.460604]
# epoch: 7100, [Discriminator :: d_loss: 0.143471], [ Generator :: loss: 3.056751]
# epoch: 7200, [Discriminator :: d_loss: 0.283301], [ Generator :: loss: 2.333473]
# epoch: 7300, [Discriminator :: d_loss: 0.244363], [ Generator :: loss: 2.538360]
# epoch: 7400, [Discriminator :: d_loss: 0.111647], [ Generator :: loss: 2.979669]
# epoch: 7500, [Discriminator :: d_loss: 0.271638], [ Generator :: loss: 2.502920]
# epoch: 7600, [Discriminator :: d_loss: 0.363232], [ Generator :: loss: 1.871043]
# epoch: 7700, [Discriminator :: d_loss: 0.127349], [ Generator :: loss: 2.917175]
# epoch: 7800, [Discriminator :: d_loss: 0.101002], [ Generator :: loss: 2.579185]
# epoch: 7900, [Discriminator :: d_loss: 0.202005], [ Generator :: loss: 1.979677]
# epoch: 8000, [Discriminator :: d_loss: 0.124895], [ Generator :: loss: 2.340981]
# epoch: 8100, [Discriminator :: d_loss: 0.238809], [ Generator :: loss: 2.213444]
# epoch: 8200, [Discriminator :: d_loss: 0.137014], [ Generator :: loss: 2.482091]
# epoch: 8300, [Discriminator :: d_loss: 0.042641], [ Generator :: loss: 3.241714]
# epoch: 8400, [Discriminator :: d_loss: 0.113485], [ Generator :: loss: 2.923381]
# epoch: 8500, [Discriminator :: d_loss: 0.181227], [ Generator :: loss: 2.531074]
# epoch: 8600, [Discriminator :: d_loss: 0.295747], [ Generator :: loss: 2.030517]
# epoch: 8700, [Discriminator :: d_loss: 0.212583], [ Generator :: loss: 2.315687]
# epoch: 8800, [Discriminator :: d_loss: 0.207368], [ Generator :: loss: 2.594620]
# epoch: 8900, [Discriminator :: d_loss: 0.069409], [ Generator :: loss: 2.913974]
# epoch: 9000, [Discriminator :: d_loss: 0.404233], [ Generator :: loss: 1.818466]
# epoch: 9100, [Discriminator :: d_loss: 0.194842], [ Generator :: loss: 2.782050]
# epoch: 9200, [Discriminator :: d_loss: 0.070961], [ Generator :: loss: 3.020969]
# epoch: 9300, [Discriminator :: d_loss: 0.176942], [ Generator :: loss: 2.380730]
# epoch: 9400, [Discriminator :: d_loss: 0.107590], [ Generator :: loss: 2.484104]
# epoch: 9500, [Discriminator :: d_loss: 0.398412], [ Generator :: loss: 2.037050]
# epoch: 9600, [Discriminator :: d_loss: 0.106490], [ Generator :: loss: 3.274873]
# epoch: 9700, [Discriminator :: d_loss: 0.174196], [ Generator :: loss: 3.357537]
# epoch: 9800, [Discriminator :: d_loss: 0.206463], [ Generator :: loss: 2.205579]
# epoch: 9900, [Discriminator :: d_loss: 0.137043], [ Generator :: loss: 2.591974]
