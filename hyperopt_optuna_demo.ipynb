# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/MachineLearning2020/blob/main/hyperopt_optuna_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Hyperopt demo - minimize x^2 function

from hyperopt import fmin, tpe, rand, hp, STATUS_OK, Trials, plotting
import matplotlib.pyplot as plt

fspace = {
    'x': hp.uniform('x', -5, 5)
}

def f(params):
    x = params['x']
    val = x**2
    return {'loss': val, 'status': STATUS_OK}
    
trials = Trials()

# possible algos: algo= (tpe.suggest, rand.suggest)
best = fmin(fn=f, space=fspace, algo=rand.suggest,  max_evals=1000, trials=trials)
print('best:', best)
print(' trials:')

#for trial in trials.trials[:2]:
#    print(trial)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 890.09it/s, best loss: 7.991198022504897e-05]
# best: {'x': -0.00893935010082103}
#  trials:

# %%
#print(trials.trials)

# %%
plotting.main_plot_history(trials)
# Out:
# avg best error: 7.991198022504897e-05

# %%
plotting.main_plot_histogram(trials)
# Out:
# Showing Histogram of 1000 jobs

# %%
plotting.main_plot_vars(trials)
# Out:
# finite loss range 7.991198022504897e-05 24.893638858069806 -0.9999200880197749

# %%
f, ax = plt.subplots(1)

xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['x'] for t in trials.trials]

ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$x$ $vs$ $t$ ', fontsize=18)
ax.set_xlabel('$t$', fontsize=16)
ax.set_ylabel('$x$', fontsize=16)
# Out:
# Text(0, 0.5, '$x$')

# %%
f, ax = plt.subplots(1)

xs = [t['misc']['vals']['x'] for t in trials.trials]
ys = [t['result']['loss'] for t in trials.trials]

ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$val$ $vs$ $x$ ', fontsize=18)
ax.set_xlabel('$x$', fontsize=16)
ax.set_ylabel('$val$', fontsize=16)
# Out:
# Text(0, 0.5, '$val$')

# %% [markdown]
# # **Optuna demo**

# %%
# install optuna
! pip install optuna

# %%
import optuna

def objective(trial):
    x = trial.suggest_uniform('x', -10, 10)
    y = trial.suggest_uniform('y', -10, 10)



    return (x - 2) ** 2 + (y-1) ** 2

study = optuna.create_study()
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(), sampler=optuna.samplers.TPESampler() )

study.optimize(objective, n_trials=200)

study.best_params  # E.g. {'x': 2.0912375440412942, 'y': 1.0091490823506173}
# Out:
# [I 2020-12-05 19:54:17,581] A new study created in memory with name: no-name-b4adc077-0505-4a44-81a2-23329f6b326a
# [I 2020-12-05 19:54:17,585] A new study created in memory with name: no-name-6043ce6a-905f-430e-9b91-e115324e2bcd
# [I 2020-12-05 19:54:17,588] Trial 0 finished with value: 146.11349937211827 and parameters: {'x': -7.72152037347613, 'y': 8.183699673580932}. Best is trial 0 with value: 146.11349937211827.
# [I 2020-12-05 19:54:17,590] Trial 1 finished with value: 11.602355965991604 and parameters: {'x': 2.1635031494532324, 'y': 4.402296678144115}. Best is trial 1 with value: 11.602355965991604.
# [I 2020-12-05 19:54:17,592] Trial 2 finished with value: 40.44955837930131 and parameters: {'x': -4.215508607726395, 'y': 2.347965550962039}. Best is trial 1 with value: 11.602355965991604.
# ...

# %% [markdown]
# ## Visualizing the Optimization History

# %%
from optuna.visualization import plot_optimization_history

plot_optimization_history(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="629c9f33-d40f-45c2-bae4-f6be41ab4a57" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("629c9f33-d40f-45c2-bae4-f6be41ab4a57")) {
#                     Plotly.newPlot(
#                         '629c9f33-d40f-45c2-bae4-f6be41ab4a57',
# ...

# %% [markdown]
# ## Visualizing High-dimensional Parameter Relationships

# %%
from optuna.visualization import plot_parallel_coordinate

plot_parallel_coordinate(study, params=['x', 'y'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="37d4ee04-1a1b-45a4-9a5d-62d932edbf34" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("37d4ee04-1a1b-45a4-9a5d-62d932edbf34")) {
#                     Plotly.newPlot(
#                         '37d4ee04-1a1b-45a4-9a5d-62d932edbf34',
# ...

# %% [markdown]
# ## Visualizing Parameter Relationships

# %%
from optuna.visualization import plot_contour

plot_contour(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd03530b-7331-40ff-94b6-db0e802fa61e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd03530b-7331-40ff-94b6-db0e802fa61e")) {
#                     Plotly.newPlot(
#                         'dd03530b-7331-40ff-94b6-db0e802fa61e',
# ...

# %% [markdown]
# ### Selecting Parameters to Visualize

# %%
plot_contour(study, params=['x', 'y'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ffa5dc1e-1f17-4a7f-b4c2-4ca0ea1932dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ffa5dc1e-1f17-4a7f-b4c2-4ca0ea1932dd")) {
#                     Plotly.newPlot(
#                         'ffa5dc1e-1f17-4a7f-b4c2-4ca0ea1932dd',
# ...

# %% [markdown]
# ## Visualizing Individual Parameters

# %%
from optuna.visualization import plot_slice

plot_slice(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="225fafa6-5f97-42b0-95a2-e5239c3a4cdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("225fafa6-5f97-42b0-95a2-e5239c3a4cdf")) {
#                     Plotly.newPlot(
#                         '225fafa6-5f97-42b0-95a2-e5239c3a4cdf',
# ...

# %% [markdown]
# ### Selecting Parameters to Visualize

# %%
plot_slice(study, params=['x', 'y'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="46ba9dd3-4c48-4aa1-8be2-73465d7696f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("46ba9dd3-4c48-4aa1-8be2-73465d7696f7")) {
#                     Plotly.newPlot(
#                         '46ba9dd3-4c48-4aa1-8be2-73465d7696f7',
# ...

# %% [markdown]
# ## Visualizing Parameter Importances

# %%
from optuna.visualization import plot_param_importances

plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b73c8e8f-0205-4e1b-9f82-1fa9a399d4f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b73c8e8f-0205-4e1b-9f82-1fa9a399d4f2")) {
#                     Plotly.newPlot(
#                         'b73c8e8f-0205-4e1b-9f82-1fa9a399d4f2',
# ...
